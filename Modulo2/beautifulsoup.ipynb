# %%
# !pip install beautifulsoup4
# !pip install pandas

# %%
# ! pip list

# %%
from bs4 import BeautifulSoup
import requests

# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

# Importar librerías para procesamiento de texto
# -----------------------------------------------------------------------
import re

# %%
url = "https://www.ebay.es/e/campanas/moviles-y-smartphones-reacondicionados"

# %%
resp_moviles = requests.get(url)

resp_moviles.status_code
# Out:
# 200

# %%
resp_moviles.content
# Out:
# b'<!DOCTYPE html><!--[if IE 9]><html class="ie9" lang="es"><![endif]--><!--[if gt IE 9]><!--><html lang="es"><!--<![endif]--><head><meta charset=utf-8><meta name="twitter:title" content="Smartphones reacondicionados | eBay. \xc2\xa1Ahorra dales una segunda vida!" /><meta name="twitter:site" content="@eBay" /><meta name="twitter:image" content="https://ir.ebaystatic.com/cr/v/c1/ebay-logo-1-1200x1200-margin.png" /><meta Property="og:type" Content="website" /><meta name="description" content="\xc2\xa1Ahorra dales una segunda vida!" /><meta Property="og:url" Content="https://www.ebay.es/e/campanas/moviles-y-smartphones-reacondicionados" /><meta name="robots" content="noindex" /><meta Property="og:description" Content="\xc2\xa1Ahorra dales una segunda vida!" /><meta Property="og:image" Content="https://ir.ebaystatic.com/cr/v/c1/ebay-logo-1-1200x630-margin.png" /><meta name="twitter:description" content="\xc2\xa1Ahorra dales una segunda vida!" /><meta property="fb:app_id" content="10262821
# ...

# %%
sopa = BeautifulSoup(resp_moviles.content, "html.parser")

sopa
# Out:
# <!DOCTYPE html>
# ...

# %%
type(sopa)
# Out:
# bs4.BeautifulSoup

# %%
sopa.find("h3")
# Out:
# <h3 class="x-refine__item"><!--F#f_0--><!--F#f_2[0]-->Categoría<!--F/--><!--F/--></h3>

# %%
sopa.find_all("h3", {"class":"s-item__title"})
# Out:
# [<h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->SMARTPHONE HUAWEI P30 Lite 128Gb<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->SMARTPHONE ONE PLUS NORD 5G 128GB 8gb  6.44  48MP  MOBILE PHONE<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->OnePlus Nord 8Gb + 128GB - Blue Libre Dual SIM (Leer Descripción)<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->LG VELVET 5G GREEN<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->XIAOMI REDMI NOTE 11 PRO 5G 128GB 8GB Gris Movil Smartphone<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->OPPO Find X3 Pro CPH2173 - 256GB - BLANCO LIBRE (Doble SIM) COMO NUEVO A++<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->Smartphone Cellulare LG Electronics LG K10 K-420 16GB 5.3" Nero<!--F/--><!--F/--></h3>,
# ...

# %%
type(sopa.find_all("h3", {"class":"s-item__title"})[0])
# Out:
# bs4.element.Tag

# %%
sopa.find_all("h3", {"class":"s-item__title"})[0]
# Out:
# <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->SMARTPHONE HUAWEI P30 Lite 128Gb<!--F/--><!--F/--></h3>

# %%
sopa.find_all("h3", {"class":"s-item__title"})[0].getText()
# Out:
# 'SMARTPHONE HUAWEI P30 Lite 128Gb'

# %%
type(sopa.find_all("h3", {"class":"s-item__title"})[0].getText())
# Out:
# str

# %%
lista_nombres = sopa.find_all("h3", {"class":"s-item__title"})

lista_nombres[1:7]
# Out:
# [<h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->SMARTPHONE ONE PLUS NORD 5G 128GB 8gb  6.44  48MP  MOBILE PHONE<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->OnePlus Nord 8Gb + 128GB - Blue Libre Dual SIM (Leer Descripción)<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->LG VELVET 5G GREEN<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->XIAOMI REDMI NOTE 11 PRO 5G 128GB 8GB Gris Movil Smartphone<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->OPPO Find X3 Pro CPH2173 - 256GB - BLANCO LIBRE (Doble SIM) COMO NUEVO A++<!--F/--><!--F/--></h3>,
#  <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->Smartphone Cellulare LG Electronics LG K10 K-420 16GB 5.3" Nero<!--F/--><!--F/--></h3>]

# %%
for telf in lista_nombres:
    print(telf)
    break
# Out:
# <h3 class="s-item__title"><!--F#f_0--><!--F#f_2[0]-->SMARTPHONE HUAWEI P30 Lite 128Gb<!--F/--><!--F/--></h3>

# %%
for telf in lista_nombres:
    print(telf.getText())
    break
# Out:
# SMARTPHONE HUAWEI P30 Lite 128Gb

# %%
nombres = []

for telf in lista_nombres:
    nombres.append(telf.getText())

# %%
nombres[:4]
# Out:
# ['SMARTPHONE HUAWEI P30 Lite 128Gb',
#  'SMARTPHONE ONE PLUS NORD 5G 128GB 8gb  6.44  48MP  MOBILE PHONE',
#  'OnePlus Nord 8Gb + 128GB - Blue Libre Dual SIM (Leer Descripción)',
#  'LG VELVET 5G GREEN']

# %%
sopa.find_all("span", {"class":"s-item__price"})
# Out:
# [<span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->80,00 EUR<!--F/--><!--F/--><!--F/--></span>,
#  <span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->139,00 EUR<!--F/--><!--F/--><!--F/--></span>,
#  <span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->89,00 EUR<!--F/--><!--F/--><!--F/--></span>,
#  <span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->180,00 EUR<!--F/--><!--F/--><!--F/--></span>,
#  <span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->52,00 EUR<!--F/--><!--F/--><!--F/--></span>,
#  <span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->239,00 EUR<!--F/--><!--F/--><!--F/--></span>,
#  <span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->28,00 EUR<!--F/--><!--F/--><!--F#f_0--><span class="DEFAULT"> a </span><!--F/--><!--F#f_0--><!--F#f_2[2]-->36,00 EUR<!--F/--><!--F/--><!--F/--></span>,
# ...

# %%
lista_precios = sopa.find_all("span", {"class":"s-item__price"})

lista_precios[:3]
# Out:
# [<span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->80,00 EUR<!--F/--><!--F/--><!--F/--></span>,
#  <span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->139,00 EUR<!--F/--><!--F/--><!--F/--></span>,
#  <span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->89,00 EUR<!--F/--><!--F/--><!--F/--></span>]

# %%
type(lista_precios[0])
# Out:
# bs4.element.Tag

# %%
lista_precios[0].getText()
# Out:
# '80,00 EUR'

# %%
precios_telefonos = []

for precio in lista_precios:
    print(precio)
    break
# Out:
# <span class="s-item__price"><!--F#f_0--><!--F#f_0--><!--F#f_2[0]-->80,00 EUR<!--F/--><!--F/--><!--F/--></span>

# %%
for precio in lista_precios:
    print(precio.getText())
    break
# Out:
# 80,00 EUR

# %%
precios_telefonos = []

for precio in lista_precios:
    precios_telefonos.append(precio.getText())

# %%
precios_telefonos[:4]
# Out:
# ['80,00 EUR', '139,00 EUR', '89,00 EUR', '180,00 EUR']

# %%
type(precios_telefonos[0])
# Out:
# str

# %%
num = '139,00 EUR'

# %%
float(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 float(num)
#
# ValueError: could not convert string to float: '139,00 EUR'

# %%
num
# Out:
# '139,00 EUR'

# %%
num.split()
# Out:
# ['139,00', 'EUR']

# %%
num.split()[0]
# Out:
# '139,00'

# %%
float(num.split()[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 float(num.split()[0])
#
# ValueError: could not convert string to float: '139,00'

# %%
num.split()[0].replace(",", ".")
# Out:
# '139.00'

# %%
type(num.split()[0].replace(",", "."))
# Out:
# str

# %%
float(num.split()[0].replace(",", "."))
# Out:
# 139.0

# %%
type(float(num.split()[0].replace(",", ".")))
# Out:
# float

# %%
num_limpio = float(num.split()[0].replace(",", "."))

num_limpio
# Out:
# 139.0

# %%
precios_telefonos
# Out:
# ['80,00 EUR',
#  '139,00 EUR',
#  '89,00 EUR',
#  '180,00 EUR',
#  '52,00 EUR',
#  '239,00 EUR',
#  '28,00 EUR a 36,00 EUR',
#  '119,00 EUR',
#  '55,00 EUR',
#  '224,60 EUR',
#  '139,00 EUR',
#  '65,00 EUR',
#  '140,00 EUR',
#  '87,00 EUR',
#  '130,00 EUR',
#  '80,00 EUR',
#  '129,00 EUR',
#  '409,00 EUR',
#  '79,95 EUR',
#  '329,00 EUR',
#  '124,00 EUR',
#  '129,95 EUR',
#  '159,00 EUR',
#  '79,00 EUR',
#  '249,00 EUR',
#  '129,99 EUR',
#  '110,00 EUR',
#  '194,35 EUR',
#  '469,00 EUR',
#  '220,41 EUR',
#  '405,65 EUR',
#  '90,00 EUR',
#  '61,00 EUR',
#  '210,00 EUR',
#  '140,00 EUR',
#  '115,00 EUR',
#  '276,97 EUR',
#  '210,00 EUR',
#  '185,00 EUR',
#  '120,00 EUR',
#  '174,39 EUR',
#  '270,00 EUR',
#  '75,00 EUR',
#  '355,07 EUR',
#  '59,00 EUR',
#  '670,00 EUR',
#  '399,00 EUR',
#  '175,00 EUR',
#  '125,95 EUR',
#  '165,00 EUR',
#  '149,00 EUR',
#  '50,00 EUR',
#  '115,00 EUR',
#  '349,00 EUR',
#  '290,00 EUR',
#  '165,30 EUR',
#  '549,00 EUR',
#  '175,00 EUR',
#  '72,00 EUR',
# ...

# %%
for precio in precios_telefonos:
    print(precio)
    break
# Out:
# 80,00 EUR

# %%
for precio in precios_telefonos:
    print(float(precio.split()[0].replace(",", ".")))
    break
# Out:
# 80.0

# %%
precios_limpio = []

for precio in precios_telefonos:
    precios_limpio.append(float(precio.split()[0].replace(",", ".")))
    
precios_limpio
# Out:
# [80.0,
#  139.0,
#  89.0,
#  180.0,
#  52.0,
#  239.0,
#  28.0,
#  119.0,
#  55.0,
#  224.6,
#  139.0,
#  65.0,
#  140.0,
#  87.0,
#  130.0,
#  80.0,
#  129.0,
#  409.0,
#  79.95,
#  329.0,
#  124.0,
#  129.95,
#  159.0,
#  79.0,
#  249.0,
#  129.99,
#  110.0,
#  194.35,
#  469.0,
#  220.41,
#  405.65,
#  90.0,
#  61.0,
#  210.0,
#  140.0,
#  115.0,
#  276.97,
#  210.0,
#  185.0,
#  120.0,
#  174.39,
#  270.0,
#  75.0,
#  355.07,
#  59.0,
#  670.0,
#  399.0,
#  175.0,
#  125.95,
#  165.0,
#  149.0,
#  50.0,
#  115.0,
#  349.0,
#  290.0,
#  165.3,
#  549.0,
#  175.0,
#  72.0,
#  57.44]
